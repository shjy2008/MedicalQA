# %%
from datasets import get_dataset_config_names
configs = get_dataset_config_names("peytonmou/EEG2Text")
print(configs)

# %%
from huggingface_hub import HfApi, hf_hub_download
import os

# # Your access token from the dataset owner
# token = "hf_xxxxxxxxxxxxxxx"

# Private repo ID
repo_id = "peytonmou/EEG2Text"

# Local folder to save the files
save_dir = "./EEG2Text"
os.makedirs(save_dir, exist_ok=True)

# Initialize API
api = HfApi()

# List all files in the repo
files = api.list_repo_files(repo_id, use_auth_token=token, repo_type="dataset")

data_files = [f for f in files if not f.startswith(".") and not f.endswith("README.md")]
print("Files to download:", data_files)

# Download each file
for file in data_files:
    print("file:", file)
    downloaded_path = hf_hub_download(
        repo_id=repo_id,
        filename=file,
        use_auth_token=token,
        repo_type="dataset"
    )
    # Move to local folder
    local_path = os.path.join(save_dir, os.path.basename(file))
    os.rename(downloaded_path, local_path)
    print(f"Downloaded: {local_path}")

print("All files downloaded!")
# Out:
# Files to download: ['s1/s1_audio1 Data.edf', 's1/s1_audio1 Data.edf.dpa', 's1/s1_audio2 Data.edf', 's1/s1_audio2 Data.edf.dpa', 's1/s1_read1 Data.edf', 's1/s1_read1 Data.edf.dpa', 's1/s1_read2 Data.edf', 's1/s1_read2 Data.edf.dpa', 's10/s10_audio1 Data.edf', 's10/s10_audio1 Data.edf.dpa', 's10/s10_audio2 Data.edf', 's10/s10_audio2 Data.edf.dpa', 's10/s10_read1 Data.edf', 's10/s10_read1 Data.edf.dpa', 's10/s10_read2 Data.edf', 's10/s10_read2 Data.edf.dpa', 's11/s11_audio1 Data.edf', 's11/s11_audio1 Data.edf.dpa', 's11/s11_audio2 Data.edf', 's11/s11_audio2 Data.edf.dpa', 's11/s11_read1 Data.edf', 's11/s11_read1 Data.edf.dpa', 's11/s11_read2 Data.edf', 's11/s11_read2 Data.edf.dpa', 's12/s12_audio1 Data.edf', 's12/s12_audio1 Data.edf.dpa', 's12/s12_audio2 Data.edf', 's12/s12_audio2 Data.edf.dpa', 's12/s12_read1 Data.edf', 's12/s12_read1 Data.edf.dpa', 's12/s12_read2 Data.edf', 's12/s12_read2 Data.edf.dpa', 's2/s2_audio1 Data.edf', 's2/s2_audio1 Data.edf.dpa', 's2/s2_audio2 Data.edf', 's2
# ...

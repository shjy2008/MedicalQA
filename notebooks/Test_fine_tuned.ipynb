# %%
import sys
print(sys.executable)

# %%
# !du -sh ./* ./.??*

# %%
# Check fine-tuned model
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# model_name = "./Documents/fine_tuned_model"
model_name = "/projects/sciences/computing/sheju347/MedicalQA/train/saved_models/fine_tuned_model_entire_UltraMedical_batch_4"
# model_name = "../../projects/sciences/computing/sheju347/MedicalQA/train/fine_tuned_model_checkpoints/checkpoint-100000"
# model_name = "../../projects/sciences/computing/sheju347/MedicalQA/train/fine_tuned_model_no_mask_1000"
# model_name = "../../projects/sciences/computing/sheju347/MedicalQA/train/fine_tuned_model_10000"
# model_name = "../../../projects/sciences/computing/sheju347/MedicalQA/train/saved_models/fine_tuned_model_no_mask_entire"
# model_name = "../../projects/sciences/computing/sheju347/MedicalQA/train/fine_tuned_model_plain_text"
# model_name = "../../../../projects/sciences/computing/sheju347/MedicalQA/train/saved_models/fine_tuned_Phi_3_mini"
# model_name = "microsoft/Phi-3-mini-4k-instruct"

# tokenizer_name = "microsoft/Phi-3-mini-4k-instruct" # model_name

tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code = False)
model = AutoModelForCausalLM.from_pretrained(model_name, trust_remote_code = False, torch_dtype=torch.bfloat16)

print(model.config.torch_dtype)
print(model.dtype)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

print("cuda available:", torch.cuda.is_available())
print("device:", device)
print("done")

# %%
from datasets import load_dataset
import re

MAX_TOKEN_OUTPUT = 1024
ENGINE_TEMPERATURE = 0.0000001
SPLIT = "test"
DATA_RANGE = None #range(0, 100)

regex_pattern=r"[\(\[]([A-Z])[\)\]]"
regex = re.compile(regex_pattern)

def format_choices(choices):
    a = zip(list(choices.keys()), choices.values())
    final_answers = []
    for x,y in a:
        final_answers.append(f'[{x}] : {y}')
    return "\n".join(final_answers)

def find_match(regex, resp, convert_dict={}):
    match = regex.findall(resp)
    if match:
        match = match[-1]
        if isinstance(match, tuple):
            match = [m for m in match if m][0]
        match = match.strip()
        if match and match in convert_dict: 
            match = convert_dict[match]
    return match
        
def extract_answer(response):
    matchFirst = re.search(r'the answer is .(\w).', response)
    if matchFirst:
        return f"({matchFirst.group(1)})"
    match = find_match(regex, response) 
    if match:
        return f"({match})"
    return "[invalid]"
        
def get_medqa_accuracy():
    # Load MedQA dataset
    # med_qa = load_dataset("bigbio/med_qa", trust_remote_code = True)
    med_qa = load_dataset("GBaker/MedQA-USMLE-4-options", trust_remote_code = True)
    keys = med_qa.keys()
    # print(len(med_qa["train"]), len(med_qa["validation"]), len(med_qa["test"]))
    
    print ("model: ", model.name_or_path)
    
    import time
    start_time = time.time()
    
    data_list = med_qa[SPLIT]
    if DATA_RANGE != None:
        data_list = data_list.select(DATA_RANGE)
    count = 0
    correct_count = 0
    for data in data_list:
        question = data["question"]
        answer_idx = data["answer_idx"]
        choices = data["options"]

        prompt = f'''\n{{question}}\n{{choices}}\n'''

        formated_choices = format_choices(choices)
        
        model_prompt = prompt.format(question = question, choices = formated_choices)
        
        messages = [{"role": "user", "content": f"{model_prompt}"}]
        inputs = tokenizer.apply_chat_template(messages, add_generation_prompt=True, return_tensors="pt").to(device)
        
        # print("messages: ", messages)
        # break
        
        # print("correct answer: ", answer_idx)
        
        # inputs = tokenizer(model_prompt, return_tensors = "pt", padding=False).to(device)
        with torch.no_grad():
            outputs = model.generate(
                inputs,
                max_new_tokens = MAX_TOKEN_OUTPUT,
                do_sample=True,
                temperature = ENGINE_TEMPERATURE,
                
                # Need these two?
                # attention_mask=inputs["attention_mask"],  # Use attention mask
                # pad_token_id=tokenizer.eos_token_id,  # Set pad token ID
                # use_cache = False, # For "microsoft/Phi-3-mini-4k-instruct"
                # do_sample = False
            )
        
        text = tokenizer.batch_decode(outputs)[0]
        # print("outputs text:", text)
        text = text.split("<|assistant|>")[-1]
        # answer = tokenizer.decode(output[0], skip_special_tokens = True)


        answer = extract_answer(text).strip("()")
        
        correct_answer = answer_idx
    
        is_correct = (answer == correct_answer)
        # print("Correct!!!" if is_correct else "Wrong")
     
    
        if is_correct:
          correct_count += 1
    
        count += 1
        
        print(f"question {count}/{len(data_list)} answer:{answer} correct_answer:{correct_answer} {is_correct}")
        
        # if count >= 10:
        #     break
    
    accuracy = correct_count / count
    print(f"Total questions: {count}, correct: {correct_count}, accuracy: {accuracy}")
    
    finish_time = time.time()
    elapse_time = finish_time - start_time
    print("elapse_time: ", elapse_time)

    return accuracy

# %%
get_medqa_accuracy()

# %%
from datasets import load_dataset
import torch
import re
import time
import logging

for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)
    
logging.basicConfig(
    filename='notebook_log_test_fine_tuned.txt',      # Log file name
    filemode='a',                    # Append mode
    format='%(asctime)s - %(levelname)s - %(message)s',
    level=logging.INFO,               # Log level
    force=True
)

class TestPerformance():

    def __init__(self, model, tokenizer, device, temperature = 0.0000001):
        self.model = model
        self.tokenizer = tokenizer
        self.device = device
        self.temperature = temperature
    
    def test_MedQA_response(self):# Test apply_chat_template // https://huggingface.co/docs/transformers/main/en/chat_templating
        print(self.model.name_or_path)

        def format_choices(choices):
            a = zip(list(choices.keys()), choices.values())
            final_answers = []
            for x,y in a:
                final_answers.append(f'[{x}] : {y}')
            return "\n".join(final_answers)


        def run_inference(content, model, tokenizer, max_new_tokens, temperature):
            messages = [{"role": "user", "content": f"{content}"}]
            # add_generation_prompt indicates the start of a response
            inputs = tokenizer.apply_chat_template(messages, add_generation_prompt = True, return_tensors = "pt").to(self.device)
            # print("inputs:", tokenizer.apply_chat_template(messages, add_generation_prompt = True, tokenize = False))
            outputs = model.generate(inputs, max_new_tokens = max_new_tokens, do_sample = True, temperature = temperature)
            text = tokenizer.batch_decode(outputs)[0]
            return text

        prompt = f'''
        {{question}} \n
        {{choices}}
        '''

        examples = [
        # Training data index 0 (GBaker/MedQA-USMLE-4-options)
        # correct: D
        {"question": "A 23-year-old pregnant woman at 22 weeks gestation presents with burning upon urination. She states it started 1 day ago and has been worsening despite drinking more water and taking cranberry extract. She otherwise feels well and is followed by a doctor for her pregnancy. Her temperature is 97.7°F (36.5°C), blood pressure is 122/77 mmHg, pulse is 80/min, respirations are 19/min, and oxygen saturation is 98% on room air. Physical exam is notable for an absence of costovertebral angle tenderness and a gravid uterus. Which of the following is the best treatment for this patient?",
        "choices": {
        "A": "Ampicillin",
        "B": "Ceftriaxone",
        "C": "Doxycycline",
        "D": "Nitrofurantoin"
        },
        "correct": "D",
        "source": "Training data index 0 (GBaker/MedQA-USMLE-4-options)"
        },

        # Training data index 1
        # correct: A
        {"question": "A 3-month-old baby died suddenly at night while asleep. His mother noticed that he had died only after she awoke in the morning. No cause of death was determined based on the autopsy. Which of the following precautions could have prevented the death of the baby?",
        "choices": {
        "A": "Placing the infant in a supine position on a firm mattress while sleeping",
        "B": "Keeping the infant covered and maintaining a high room temperature",
        "C": "Application of a device to maintain the sleeping position",
        "D": "Avoiding pacifier use during sleep"
        },
        "correct": "A",
        "source": "Training data index 1 (GBaker/MedQA-USMLE-4-options)"
        },

        # Training data index 2
        # correct: A
        {"question": "A mother brings her 3-week-old infant to the pediatrician's office because she is concerned about his feeding habits. He was born without complications and has not had any medical problems up until this time. However, for the past 4 days, he has been fussy, is regurgitating all of his feeds, and his vomit is yellow in color. On physical exam, the child's abdomen is minimally distended but no other abnormalities are appreciated. Which of the following embryologic errors could account for this presentation?",
        "choices": {
        "A": "Abnormal migration of ventral pancreatic bud",
        "B": "Complete failure of proximal duodenum to recanalize",
        "C": "Abnormal hypertrophy of the pylorus",
        "D": "Failure of lateral body folds to move ventrally and fuse in the midline"
        },
        "correct": "A",
        "source": "Training data index 2 (GBaker/MedQA-USMLE-4-options)"
        },

        # Test data index 0
        # correct: B
        {"question": "A junior orthopaedic surgery resident is completing a carpal tunnel repair with the department chairman as the attending physician. During the case, the resident inadvertently cuts a flexor tendon. The tendon is repaired without complication. The attending tells the resident that the patient will do fine, and there is no need to report this minor complication that will not harm the patient, as he does not want to make the patient worry unnecessarily. He tells the resident to leave this complication out of the operative report. Which of the following is the correct next action for the resident to take?",
        "choices":{
        "A": "Disclose the error to the patient and put it in the operative report",
        "B": "Tell the attending that he cannot fail to disclose this mistake",
        "C": "Report the physician to the ethics committee",
        "D": "Refuse to dictate the operative report"
        },
        "correct": "B",
        "source": "Test data index 0 (GBaker/MedQA-USMLE-4-options)"
        },

        ]

        for example in examples:
            formated_choices = format_choices(example["choices"])
    
            model_prompt = prompt.format(question = example["question"], choices = formated_choices)
    
            # print(model_prompt)
    
            output_text = run_inference(model_prompt, self.model, self.tokenizer, max_new_tokens = 1024, temperature = self.temperature)
            # output_text = output_text.split("<|assistant|>")[-1]
            print("model output:", output_text)
            print("\nsource: ", example["source"])
            print("correct: ", example["correct"])
            print("\n\n")

    def test_MedQA_test_data_accuracy(self, is_ensemble = False):

        MAX_TOKEN_OUTPUT = 1024
        SPLIT = "test"
        DATA_RANGE = None #range(627, 643)

        regex_pattern=r"[\(\[]([A-Z])[\)\]]"
        regex = re.compile(regex_pattern)

        def format_choices(choices):
            a = zip(list(choices.keys()), choices.values())
            final_answers = []
            for x,y in a:
                final_answers.append(f'[{x}] : {y}')
            return "\n".join(final_answers)

        def find_match(regex, resp, convert_dict={}):
            match = regex.findall(resp)
            if match:
                match = match[-1]
                if isinstance(match, tuple):
                    match = [m for m in match if m][0]
                match = match.strip()
                if match and match in convert_dict: 
                    match = convert_dict[match]
            return match
                
        def extract_answer(response):
            matchFirst = re.search(r'the answer is .(\w).', response)
            if matchFirst:
                return f"({matchFirst.group(1)})"
            match = find_match(regex, response) 
            if match:
                return f"({match})"
            return "[invalid]"

        def run_inference_get_answer_letter(inputs, temperature):
            with torch.no_grad():
                outputs = self.model.generate(
                    inputs,
                    max_new_tokens = MAX_TOKEN_OUTPUT,
                    do_sample=True,
                    temperature = temperature,
                )

            # print("temperature:", temperature)
            # print("inputs", inputs)
            
            text = self.tokenizer.batch_decode(outputs)[0]
            # print("outputs text:", text)
            text = text.split("<|assistant|>")[-1]
            # answer = tokenizer.decode(output[0], skip_special_tokens = True)

            answer = extract_answer(text).strip("()")
            
            print(f"answer: {answer}")
            logging.info(f"answer: {answer}")
            
            return answer
                
        def get_medqa_accuracy():
            # Load MedQA dataset
            # med_qa = load_dataset("bigbio/med_qa", trust_remote_code = True)
            med_qa = load_dataset("GBaker/MedQA-USMLE-4-options", trust_remote_code = True)
            keys = med_qa.keys()
            # print(len(med_qa["train"]), len(med_qa["validation"]), len(med_qa["test"]))

            print(f"model: {self.model.name_or_path}")
            logging.info(f"model: {self.model.name_or_path}")
            
            start_time = time.time()
            
            data_list = med_qa[SPLIT]
            if DATA_RANGE != None:
                data_list = data_list.select(DATA_RANGE)
            count = 0
            correct_count = 0
            for data in data_list:
                question = data["question"]
                answer_idx = data["answer_idx"]
                choices = data["options"]

                prompt = f'''\n{{question}}\n{{choices}}\n'''

                formated_choices = format_choices(choices)
                
                model_prompt = prompt.format(question = question, choices = formated_choices)
                
                messages = [{"role": "user", "content": f"{model_prompt}"}]
                inputs = self.tokenizer.apply_chat_template(messages, add_generation_prompt=True, return_tensors="pt").to(self.device)
                
                # print("messages: ", messages)
                # break
                
                # print("correct answer: ", answer_idx)

                if is_ensemble:
                    answer_dict = {}
                    for i in range(0, 5):
                        # inputs = tokenizer(model_prompt, return_tensors = "pt", padding=False).to(device)
                        current_answer = run_inference_get_answer_letter(inputs, temperature = 0.7)
                        if current_answer in answer_dict:
                            answer_dict[current_answer] += 1
                        else:
                            answer_dict[current_answer] = 1
                    answer = max(answer_dict, key = answer_dict.get)
                else:
                    answer = run_inference_get_answer_letter(inputs, temperature = self.temperature)
                
                correct_answer = answer_idx
            
                is_correct = (answer == correct_answer)
                # print("Correct!!!" if is_correct else "Wrong")
            
            
                if is_correct:
                    correct_count += 1
            
                count += 1

                print(f"question {count}/{len(data_list)} answer:{answer} correct_answer:{correct_answer} {is_correct}")
                logging.info(f"question {count}/{len(data_list)} answer:{answer} correct_answer:{correct_answer} {is_correct}")
            
            accuracy = correct_count / count
            print(f"Total questions: {count}, correct: {correct_count}, accuracy: {accuracy}")
            logging.info(f"Total questions: {count}, correct: {correct_count}, accuracy: {accuracy}")
            
            finish_time = time.time()
            elapse_time = finish_time - start_time
            print(f"elapse_time: {elapse_time}")
            logging.info(f"elapse_time: {elapse_time}")

            return accuracy

        get_medqa_accuracy()

# %%
test = TestPerformance(model, tokenizer, device)
# test.test_MedQA_response()
test.test_MedQA_test_data_accuracy(is_ensemble = False)
# test.test_MedQA_test_data_accuracy(is_ensemble = True)
# Out:
# model: /projects/sciences/computing/sheju347/MedicalQA/train/saved_models/fine_tuned_model_entire_UltraMedical_batch_4
# answer: A
# question 1/1273 answer:A correct_answer:B False
# answer: D
# question 2/1273 answer:D correct_answer:D True
# answer: B
# question 3/1273 answer:B correct_answer:B True
# answer: B
# question 4/1273 answer:B correct_answer:D False
# answer: B
# question 5/1273 answer:B correct_answer:B True
# answer: B
# question 6/1273 answer:B correct_answer:D False
# answer: B
# question 7/1273 answer:B correct_answer:C False
# answer: C
# question 8/1273 answer:C correct_answer:C True
# answer: B
# question 9/1273 answer:B correct_answer:B True
# answer: A
# question 10/1273 answer:A correct_answer:A True
# answer: D
# question 11/1273 answer:D correct_answer:D True
# answer: D
# question 12/1273 answer:D correct_answer:D True
# answer: B
# question 13/1273 answer:B correct_answer:B True
# answer: D
# question 14/1273 answer:D correct_answer:D True
# answer: C
# question 15/1273 answer:C correct_answer:C True
# answer: B
# question 16/1273 answer:B correct_answer:B True
# answer: D
# question 17/1273 answer:D correct_answer:D True
# answer: D
# question 18/1273 answer:D correct_answer:D True
# answer: B
# question 19/1273 answer:B correct_answer:B True
# answer: B
# question 20/1273 answer:B correct_answer:D False
# answer: C
# question 21/1273 answer:C correct_answer:C True
# answer: A
# question 22/1273 answer:A correct_answer:A True
# answer: C
# question 23/1273 answer:C correct_answer:C True
# answer: A
# question 24/1273 answer:A correct_answer:D False
# answer: A
# question 25/1273 answer:A correct_answer:A True
# answer: C
# question 26/1273 answer:C correct_answer:D False
# answer: D
# question 27/1273 answer:D correct_answer:D True
# answer: A
# question 28/1273 answer:A correct_answer:A True
# answer: D
# question 29/1273 answer:D correct_answer:D True
# answer: A
# question 30/1273 answer:A correct_answer:C False
# answer: A
# question 31/1273 answer:A correct_answer:D False
# answer: C
# question 32/1273 answer:C correct_answer:C True
# answer: D
# question 33/1273 answer:D correct_answer:D True
# answer: C
# question 34/1273 answer:C correct_answer:B False
# answer: A
# question 35/1273 answer:A correct_answer:A True
# answer: A
# question 36/1273 answer:A correct_answer:A True
# answer: D
# question 37/1273 answer:D correct_answer:D True
# answer: A
# question 38/1273 answer:A correct_answer:A True
# answer: C
# question 39/1273 answer:C correct_answer:D False
# answer: D
# question 40/1273 answer:D correct_answer:A False
# answer: C
# question 41/1273 answer:C correct_answer:C True
# answer: C
# question 42/1273 answer:C correct_answer:C True
# answer: A
# question 43/1273 answer:A correct_answer:A True
# answer: B
# question 44/1273 answer:B correct_answer:B True
# answer: A
# question 45/1273 answer:A correct_answer:A True
# answer: A
# question 46/1273 answer:A correct_answer:D False
# answer: C
# question 47/1273 answer:C correct_answer:C True
# answer: A
# question 48/1273 answer:A correct_answer:A True
# answer: B
# question 49/1273 answer:B correct_answer:B True
# answer: C
# question 50/1273 answer:C correct_answer:C True
# answer: D
# question 51/1273 answer:D correct_answer:D True
# answer: A
# question 52/1273 answer:A correct_answer:A True
# answer: D
# question 53/1273 answer:D correct_answer:D True
# answer: B
# question 54/1273 answer:B correct_answer:C False
# answer: A
# question 55/1273 answer:A correct_answer:A True
# answer: A
# question 56/1273 answer:A correct_answer:A True
# answer: C
# question 57/1273 answer:C correct_answer:C True
# answer: B
# question 58/1273 answer:B correct_answer:B True
# answer: C
# question 59/1273 answer:C correct_answer:C True
# answer: C
# question 60/1273 answer:C correct_answer:A False
# answer: C
# question 61/1273 answer:C correct_answer:C True
# answer: A
# question 62/1273 answer:A correct_answer:A True
# answer: A
# question 63/1273 answer:A correct_answer:D False
# answer: A
# question 64/1273 answer:A correct_answer:A True
# answer: A
# question 65/1273 answer:A correct_answer:A True
# answer: B
# question 66/1273 answer:B correct_answer:B True
# answer: C
# question 67/1273 answer:C correct_answer:C True
# answer: B
# question 68/1273 answer:B correct_answer:B True
# answer: C
# question 69/1273 answer:C correct_answer:D False
# answer: A
# question 70/1273 answer:A correct_answer:A True
# answer: A
# question 71/1273 answer:A correct_answer:A True
# answer: A
# question 72/1273 answer:A correct_answer:A True
# answer: C
# question 73/1273 answer:C correct_answer:C True
# answer: B
# question 74/1273 answer:B correct_answer:B True
# answer: A
# question 75/1273 answer:A correct_answer:C False
# answer: A
# question 76/1273 answer:A correct_answer:A True
# answer: B
# question 77/1273 answer:B correct_answer:B True
# answer: B
# question 78/1273 answer:B correct_answer:B True
# answer: C
# question 79/1273 answer:C correct_answer:C True
# answer: C
# question 80/1273 answer:C correct_answer:C True
# answer: B
# question 81/1273 answer:B correct_answer:B True
# answer: C
# question 82/1273 answer:C correct_answer:A False
# answer: C
# question 83/1273 answer:C correct_answer:C True
# answer: A
# question 84/1273 answer:A correct_answer:A True
# answer: C
# question 85/1273 answer:C correct_answer:C True
# answer: B
# question 86/1273 answer:B correct_answer:B True
# answer: C
# question 87/1273 answer:C correct_answer:C True
# answer: C
# question 88/1273 answer:C correct_answer:C True
# answer: B
# question 89/1273 answer:B correct_answer:C False
# answer: B
# question 90/1273 answer:B correct_answer:B True
# answer: D
# question 91/1273 answer:D correct_answer:D True
# answer: C
# question 92/1273 answer:C correct_answer:B False
# answer: C
# question 93/1273 answer:C correct_answer:C True
# answer: A
# question 94/1273 answer:A correct_answer:D False
# answer: A
# question 95/1273 answer:A correct_answer:C False
# answer: D
# question 96/1273 answer:D correct_answer:D True
# answer: A
# question 97/1273 answer:A correct_answer:A True
# answer: B
# question 98/1273 answer:B correct_answer:B True
# answer: B
# question 99/1273 answer:B correct_answer:B True
# answer: B
# question 100/1273 answer:B correct_answer:B True
# answer: B
# question 101/1273 answer:B correct_answer:D False
# answer: A
# question 102/1273 answer:A correct_answer:A True
# answer: A
# question 103/1273 answer:A correct_answer:A True
# answer: A
# question 104/1273 answer:A correct_answer:A True
# answer: B
# question 105/1273 answer:B correct_answer:B True
# answer: B
# question 106/1273 answer:B correct_answer:B True
# answer: A
# question 107/1273 answer:A correct_answer:B False
# answer: A
# question 108/1273 answer:A correct_answer:A True
# answer: B
# question 109/1273 answer:B correct_answer:D False
# answer: C
# question 110/1273 answer:C correct_answer:B False
# answer: C
# question 111/1273 answer:C correct_answer:C True
# answer: B
# question 112/1273 answer:B correct_answer:B True
# answer: A
# question 113/1273 answer:A correct_answer:B False
# answer: C
# question 114/1273 answer:C correct_answer:C True
# answer: C
# question 115/1273 answer:C correct_answer:C True
# answer: D
# question 116/1273 answer:D correct_answer:D True
# answer: C
# question 117/1273 answer:C correct_answer:C True
# answer: C
# question 118/1273 answer:C correct_answer:C True
# answer: D
# question 119/1273 answer:D correct_answer:D True
# answer: C
# question 120/1273 answer:C correct_answer:C True
# answer: D
# question 121/1273 answer:D correct_answer:D True
# answer: A
# question 122/1273 answer:A correct_answer:A True
# answer: D
# question 123/1273 answer:D correct_answer:D True
# answer: A
# question 124/1273 answer:A correct_answer:A True
# answer: B
# question 125/1273 answer:B correct_answer:B True
# answer: A
# question 126/1273 answer:A correct_answer:A True
# answer: A
# question 127/1273 answer:A correct_answer:A True
# answer: C
# question 128/1273 answer:C correct_answer:C True
# answer: B
# question 129/1273 answer:B correct_answer:A False
# answer: A
# question 130/1273 answer:A correct_answer:A True
# answer: B
# question 131/1273 answer:B correct_answer:B True
# answer: B
# question 132/1273 answer:B correct_answer:B True
# answer: A
# question 133/1273 answer:A correct_answer:A True
# answer: B
# question 134/1273 answer:B correct_answer:B True
# answer: A
# question 135/1273 answer:A correct_answer:A True
# answer: C
# question 136/1273 answer:C correct_answer:C True
# answer: C
# question 137/1273 answer:C correct_answer:C True
# answer: D
# question 138/1273 answer:D correct_answer:D True
# answer: B
# question 139/1273 answer:B correct_answer:B True
# answer: A
# question 140/1273 answer:A correct_answer:D False
# answer: C
# question 141/1273 answer:C correct_answer:C True
# answer: A
# question 142/1273 answer:A correct_answer:A True
# answer: A
# question 143/1273 answer:A correct_answer:A True
# answer: B
# question 144/1273 answer:B correct_answer:B True
# answer: D
# question 145/1273 answer:D correct_answer:C False
# answer: B
# question 146/1273 answer:B correct_answer:D False
# answer: D
# question 147/1273 answer:D correct_answer:C False
# answer: D
# question 148/1273 answer:D correct_answer:D True
# answer: B
# question 149/1273 answer:B correct_answer:B True
# answer: A
# question 150/1273 answer:A correct_answer:D False
# answer: B
# question 151/1273 answer:B correct_answer:A False
# answer: D
# question 152/1273 answer:D correct_answer:D True
# answer: A
# question 153/1273 answer:A correct_answer:A True
# answer: A
# question 154/1273 answer:A correct_answer:A True
# answer: C
# question 155/1273 answer:C correct_answer:C True
# answer: D
# question 156/1273 answer:D correct_answer:D True
# answer: A
# question 157/1273 answer:A correct_answer:B False
# answer: C
# question 158/1273 answer:C correct_answer:A False
# answer: C
# question 159/1273 answer:C correct_answer:C True
# answer: B
# question 160/1273 answer:B correct_answer:B True
# answer: C
# question 161/1273 answer:C correct_answer:C True
# answer: B
# question 162/1273 answer:B correct_answer:B True
# answer: C
# question 163/1273 answer:C correct_answer:C True
# answer: D
# question 164/1273 answer:D correct_answer:A False
# answer: A
# question 165/1273 answer:A correct_answer:A True
# answer: C
# question 166/1273 answer:C correct_answer:B False
# answer: A
# question 167/1273 answer:A correct_answer:B False
# answer: C
# question 168/1273 answer:C correct_answer:C True
# answer: B
# question 169/1273 answer:B correct_answer:B True
# answer: C
# question 170/1273 answer:C correct_answer:C True
# answer: C
# question 171/1273 answer:C correct_answer:C True
# answer: C
# question 172/1273 answer:C correct_answer:D False
# answer: B
# question 173/1273 answer:B correct_answer:C False
# answer: A
# question 174/1273 answer:A correct_answer:A True
# answer: D
# question 175/1273 answer:D correct_answer:D True
# answer: D
# question 176/1273 answer:D correct_answer:D True
# answer: D
# question 177/1273 answer:D correct_answer:D True
# answer: C
# question 178/1273 answer:C correct_answer:C True
# answer: A
# question 179/1273 answer:A correct_answer:D False
# answer: C
# question 180/1273 answer:C correct_answer:C True
# answer: C
# question 181/1273 answer:C correct_answer:B False
# answer: D
# question 182/1273 answer:D correct_answer:D True
# answer: C
# question 183/1273 answer:C correct_answer:B False
# answer: D
# question 184/1273 answer:D correct_answer:D True
# answer: A
# question 185/1273 answer:A correct_answer:A True
# answer: D
# question 186/1273 answer:D correct_answer:D True
# answer: B
# question 187/1273 answer:B correct_answer:B True
# answer: B
# question 188/1273 answer:B correct_answer:B True
# answer: C
# question 189/1273 answer:C correct_answer:D False
# answer: C
# question 190/1273 answer:C correct_answer:C True
# answer: A
# question 191/1273 answer:A correct_answer:A True
# answer: C
# question 192/1273 answer:C correct_answer:C True
# answer: D
# question 193/1273 answer:D correct_answer:D True
# answer: C
# question 194/1273 answer:C correct_answer:C True
# answer: C
# question 195/1273 answer:C correct_answer:C True
# answer: C
# question 196/1273 answer:C correct_answer:C True
# answer: D
# question 197/1273 answer:D correct_answer:A False
# answer: B
# question 198/1273 answer:B correct_answer:B True
# answer: C
# question 199/1273 answer:C correct_answer:D False
# answer: B
# question 200/1273 answer:B correct_answer:C False
# answer: A
# question 201/1273 answer:A correct_answer:A True
# answer: B
# question 202/1273 answer:B correct_answer:B True
# answer: B
# question 203/1273 answer:B correct_answer:C False
# answer: B
# question 204/1273 answer:B correct_answer:A False
# answer: C
# question 205/1273 answer:C correct_answer:B False
# answer: B
# question 206/1273 answer:B correct_answer:B True
# answer: C
# question 207/1273 answer:C correct_answer:C True
# answer: A
# question 208/1273 answer:A correct_answer:A True
# answer: B
# question 209/1273 answer:B correct_answer:B True
# answer: A
# question 210/1273 answer:A correct_answer:A True
# answer: C
# question 211/1273 answer:C correct_answer:C True
# answer: D
# question 212/1273 answer:D correct_answer:B False
# answer: B
# question 213/1273 answer:B correct_answer:D False
# answer: A
# question 214/1273 answer:A correct_answer:A True
# answer: B
# question 215/1273 answer:B correct_answer:B True
# answer: C
# question 216/1273 answer:C correct_answer:C True
# answer: D
# question 217/1273 answer:D correct_answer:D True
# answer: C
# question 218/1273 answer:C correct_answer:C True
# answer: D
# question 219/1273 answer:D correct_answer:D True
# answer: C
# question 220/1273 answer:C correct_answer:A False
# answer: C
# question 221/1273 answer:C correct_answer:C True
# answer: A
# question 222/1273 answer:A correct_answer:A True
# answer: D
# question 223/1273 answer:D correct_answer:C False
# answer: A
# question 224/1273 answer:A correct_answer:A True
# answer: C
# question 225/1273 answer:C correct_answer:B False
# answer: C
# question 226/1273 answer:C correct_answer:C True
# answer: C
# question 227/1273 answer:C correct_answer:C True
# answer: C
# question 228/1273 answer:C correct_answer:C True
# answer: A
# question 229/1273 answer:A correct_answer:A True
# answer: D
# question 230/1273 answer:D correct_answer:D True
# answer: B
# question 231/1273 answer:B correct_answer:B True
# answer: C
# question 232/1273 answer:C correct_answer:A False
# answer: C
# question 233/1273 answer:C correct_answer:C True
# answer: A
# question 234/1273 answer:A correct_answer:A True
# answer: D
# question 235/1273 answer:D correct_answer:C False
# answer: A
# question 236/1273 answer:A correct_answer:A True
# answer: A
# question 237/1273 answer:A correct_answer:A True
# answer: D
# question 238/1273 answer:D correct_answer:B False
# answer: B
# question 239/1273 answer:B correct_answer:A False
# answer: C
# question 240/1273 answer:C correct_answer:A False
# answer: D
# question 241/1273 answer:D correct_answer:D True
# answer: A
# question 242/1273 answer:A correct_answer:B False
# answer: A
# question 243/1273 answer:A correct_answer:A True
# answer: D
# question 244/1273 answer:D correct_answer:A False
# answer: B
# question 245/1273 answer:B correct_answer:D False
# answer: C
# question 246/1273 answer:C correct_answer:C True
# answer: B
# question 247/1273 answer:B correct_answer:A False
# answer: D
# question 248/1273 answer:D correct_answer:D True
# answer: C
# question 249/1273 answer:C correct_answer:B False
# answer: B
# question 250/1273 answer:B correct_answer:B True
# answer: D
# question 251/1273 answer:D correct_answer:A False
# answer: B
# question 252/1273 answer:B correct_answer:B True
# answer: A
# question 253/1273 answer:A correct_answer:A True
# answer: D
# question 254/1273 answer:D correct_answer:D True
# answer: A
# question 255/1273 answer:A correct_answer:A True
# answer: C
# question 256/1273 answer:C correct_answer:C True
# answer: C
# question 257/1273 answer:C correct_answer:C True
# answer: A
# question 258/1273 answer:A correct_answer:D False
# answer: A
# question 259/1273 answer:A correct_answer:D False
# answer: D
# question 260/1273 answer:D correct_answer:D True
# answer: D
# question 261/1273 answer:D correct_answer:C False
# answer: C
# question 262/1273 answer:C correct_answer:C True
# answer: A
# question 263/1273 answer:A correct_answer:D False
# answer: D
# question 264/1273 answer:D correct_answer:C False
# answer: C
# question 265/1273 answer:C correct_answer:A False
# answer: A
# question 266/1273 answer:A correct_answer:D False
# answer: A
# question 267/1273 answer:A correct_answer:A True
# answer: D
# question 268/1273 answer:D correct_answer:D True
# answer: D
# question 269/1273 answer:D correct_answer:D True
# answer: C
# question 270/1273 answer:C correct_answer:C True
# answer: C
# question 271/1273 answer:C correct_answer:C True
# answer: B
# question 272/1273 answer:B correct_answer:B True
# answer: C
# question 273/1273 answer:C correct_answer:C True
# answer: D
# question 274/1273 answer:D correct_answer:A False
# answer: A
# question 275/1273 answer:A correct_answer:A True
# answer: A
# question 276/1273 answer:A correct_answer:A True
# answer: D
# question 277/1273 answer:D correct_answer:C False
# answer: D
# question 278/1273 answer:D correct_answer:D True
# answer: C
# question 279/1273 answer:C correct_answer:A False
# answer: B
# question 280/1273 answer:B correct_answer:B True
# answer: B
# question 281/1273 answer:B correct_answer:B True
# answer: C
# question 282/1273 answer:C correct_answer:C True
# answer: A
# question 283/1273 answer:A correct_answer:A True
# answer: A
# question 284/1273 answer:A correct_answer:A True
# answer: A
# question 285/1273 answer:A correct_answer:A True
# answer: D
# question 286/1273 answer:D correct_answer:C False
# answer: C
# question 287/1273 answer:C correct_answer:C True
# answer: C
# question 288/1273 answer:C correct_answer:A False
# answer: D
# question 289/1273 answer:D correct_answer:B False
# answer: C
# question 290/1273 answer:C correct_answer:C True
# answer: D
# question 291/1273 answer:D correct_answer:B False
# answer: D
# question 292/1273 answer:D correct_answer:A False
# answer: D
# question 293/1273 answer:D correct_answer:C False
# answer: A
# question 294/1273 answer:A correct_answer:A True
# answer: A
# question 295/1273 answer:A correct_answer:A True
# answer: A
# question 296/1273 answer:A correct_answer:A True
# answer: A
# question 297/1273 answer:A correct_answer:A True
# answer: D
# question 298/1273 answer:D correct_answer:D True
# answer: D
# question 299/1273 answer:D correct_answer:D True
# answer: B
# question 300/1273 answer:B correct_answer:B True
# answer: B
# question 301/1273 answer:B correct_answer:D False
# answer: A
# question 302/1273 answer:A correct_answer:C False
# answer: A
# question 303/1273 answer:A correct_answer:A True
# answer: D
# question 304/1273 answer:D correct_answer:C False
# answer: A
# question 305/1273 answer:A correct_answer:A True
# answer: A
# question 306/1273 answer:A correct_answer:B False
# answer: A
# question 307/1273 answer:A correct_answer:C False
# answer: A
# question 308/1273 answer:A correct_answer:C False
# answer: C
# question 309/1273 answer:C correct_answer:C True
# answer: D
# question 310/1273 answer:D correct_answer:D True
# answer: B
# question 311/1273 answer:B correct_answer:B True
# answer: C
# question 312/1273 answer:C correct_answer:C True
# answer: B
# question 313/1273 answer:B correct_answer:B True
# answer: B
# question 314/1273 answer:B correct_answer:B True
# answer: B
# question 315/1273 answer:B correct_answer:A False
# answer: A
# question 316/1273 answer:A correct_answer:A True
# answer: B
# question 317/1273 answer:B correct_answer:A False
# answer: D
# question 318/1273 answer:D correct_answer:A False
# answer: D
# question 319/1273 answer:D correct_answer:C False
# answer: A
# question 320/1273 answer:A correct_answer:A True
# answer: C
# question 321/1273 answer:C correct_answer:C True
# answer: D
# question 322/1273 answer:D correct_answer:A False
# answer: C
# question 323/1273 answer:C correct_answer:C True
# answer: C
# question 324/1273 answer:C correct_answer:C True
# answer: A
# question 325/1273 answer:A correct_answer:A True
# answer: B
# question 326/1273 answer:B correct_answer:B True
# answer: A
# question 327/1273 answer:A correct_answer:A True
# answer: B
# question 328/1273 answer:B correct_answer:A False
# answer: A
# question 329/1273 answer:A correct_answer:A True
# answer: A
# question 330/1273 answer:A correct_answer:B False
# answer: B
# question 331/1273 answer:B correct_answer:B True
# answer: B
# question 332/1273 answer:B correct_answer:B True
# answer: A
# question 333/1273 answer:A correct_answer:D False
# answer: B
# question 334/1273 answer:B correct_answer:D False
# answer: B
# question 335/1273 answer:B correct_answer:B True
# answer: A
# question 336/1273 answer:A correct_answer:A True
# answer: B
# question 337/1273 answer:B correct_answer:A False
# answer: D
# question 338/1273 answer:D correct_answer:B False
# answer: A
# question 339/1273 answer:A correct_answer:A True
# answer: A
# question 340/1273 answer:A correct_answer:A True
# answer: A
# question 341/1273 answer:A correct_answer:D False
# answer: C
# question 342/1273 answer:C correct_answer:B False
# answer: C
# question 343/1273 answer:C correct_answer:C True
# answer: A
# question 344/1273 answer:A correct_answer:A True
# answer: A
# question 345/1273 answer:A correct_answer:A True
# answer: B
# question 346/1273 answer:B correct_answer:B True
# answer: B
# question 347/1273 answer:B correct_answer:B True
# answer: A
# question 348/1273 answer:A correct_answer:A True
# answer: C
# question 349/1273 answer:C correct_answer:C True
# answer: B
# question 350/1273 answer:B correct_answer:B True
# answer: C
# question 351/1273 answer:C correct_answer:B False
# answer: B
# question 352/1273 answer:B correct_answer:A False
# answer: D
# question 353/1273 answer:D correct_answer:A False
# answer: C
# question 354/1273 answer:C correct_answer:B False
# answer: C
# question 355/1273 answer:C correct_answer:C True
# answer: A
# question 356/1273 answer:A correct_answer:A True
# answer: D
# question 357/1273 answer:D correct_answer:A False
# answer: D
# question 358/1273 answer:D correct_answer:D True
# answer: C
# question 359/1273 answer:C correct_answer:B False
# answer: C
# question 360/1273 answer:C correct_answer:C True
# answer: C
# question 361/1273 answer:C correct_answer:A False
# answer: A
# question 362/1273 answer:A correct_answer:A True
# answer: D
# question 363/1273 answer:D correct_answer:D True
# answer: C
# question 364/1273 answer:C correct_answer:C True
# answer: D
# question 365/1273 answer:D correct_answer:A False
# answer: C
# question 366/1273 answer:C correct_answer:C True
# answer: A
# question 367/1273 answer:A correct_answer:A True
# answer: A
# question 368/1273 answer:A correct_answer:D False
# answer: C
# question 369/1273 answer:C correct_answer:C True
# answer: D
# question 370/1273 answer:D correct_answer:D True
# answer: D
# question 371/1273 answer:D correct_answer:D True
# answer: C
# question 372/1273 answer:C correct_answer:A False
# answer: D
# question 373/1273 answer:D correct_answer:D True
# answer: D
# question 374/1273 answer:D correct_answer:D True
# answer: D
# question 375/1273 answer:D correct_answer:D True
# answer: B
# question 376/1273 answer:B correct_answer:B True
# answer: B
# question 377/1273 answer:B correct_answer:D False
# answer: D
# question 378/1273 answer:D correct_answer:D True
# answer: C
# question 379/1273 answer:C correct_answer:A False
# answer: C
# question 380/1273 answer:C correct_answer:C True
# answer: C
# question 381/1273 answer:C correct_answer:B False
# answer: D
# question 382/1273 answer:D correct_answer:C False
# answer: D
# question 383/1273 answer:D correct_answer:C False
# answer: A
# question 384/1273 answer:A correct_answer:A True
# answer: D
# question 385/1273 answer:D correct_answer:D True
# answer: D
# question 386/1273 answer:D correct_answer:D True
# answer: C
# question 387/1273 answer:C correct_answer:C True
# answer: B
# question 388/1273 answer:B correct_answer:B True
# answer: C
# question 389/1273 answer:C correct_answer:C True
# answer: D
# question 390/1273 answer:D correct_answer:D True
# answer: A
# question 391/1273 answer:A correct_answer:A True
# answer: A
# question 392/1273 answer:A correct_answer:A True
# answer: C
# question 393/1273 answer:C correct_answer:C True
# answer: D
# question 394/1273 answer:D correct_answer:A False
# answer: C
# question 395/1273 answer:C correct_answer:C True
# answer: B
# question 396/1273 answer:B correct_answer:B True
# answer: D
# question 397/1273 answer:D correct_answer:D True
# answer: A
# question 398/1273 answer:A correct_answer:A True
# answer: D
# question 399/1273 answer:D correct_answer:D True
# answer: A
# question 400/1273 answer:A correct_answer:B False
# answer: B
# question 401/1273 answer:B correct_answer:B True
# answer: A
# question 402/1273 answer:A correct_answer:C False
# answer: A
# question 403/1273 answer:A correct_answer:A True
# answer: D
# question 404/1273 answer:D correct_answer:D True
# answer: B
# question 405/1273 answer:B correct_answer:A False
# answer: A
# question 406/1273 answer:A correct_answer:A True
# answer: B
# question 407/1273 answer:B correct_answer:B True
# answer: B
# question 408/1273 answer:B correct_answer:B True
# answer: A
# question 409/1273 answer:A correct_answer:A True
# answer: C
# question 410/1273 answer:C correct_answer:C True
# answer: C
# question 411/1273 answer:C correct_answer:C True
# answer: B
# question 412/1273 answer:B correct_answer:B True
# answer: A
# question 413/1273 answer:A correct_answer:A True
# answer: C
# question 414/1273 answer:C correct_answer:A False
# answer: C
# question 415/1273 answer:C correct_answer:D False
# answer: D
# question 416/1273 answer:D correct_answer:D True
# answer: C
# question 417/1273 answer:C correct_answer:C True
# answer: A
# question 418/1273 answer:A correct_answer:A True
# answer: C
# question 419/1273 answer:C correct_answer:C True
# answer: C
# question 420/1273 answer:C correct_answer:B False
# answer: B
# question 421/1273 answer:B correct_answer:B True
# answer: C
# question 422/1273 answer:C correct_answer:C True
# answer: A
# question 423/1273 answer:A correct_answer:A True
# answer: D
# question 424/1273 answer:D correct_answer:D True
# answer: C
# question 425/1273 answer:C correct_answer:C True
# answer: C
# question 426/1273 answer:C correct_answer:C True
# answer: B
# question 427/1273 answer:B correct_answer:B True
# answer: B
# question 428/1273 answer:B correct_answer:B True
# answer: A
# question 429/1273 answer:A correct_answer:A True
# answer: D
# question 430/1273 answer:D correct_answer:D True
# answer: A
# question 431/1273 answer:A correct_answer:A True
# answer: B
# question 432/1273 answer:B correct_answer:B True
# answer: A
# question 433/1273 answer:A correct_answer:A True
# answer: C
# question 434/1273 answer:C correct_answer:C True
# answer: B
# question 435/1273 answer:B correct_answer:B True
# answer: C
# question 436/1273 answer:C correct_answer:C True
# answer: C
# question 437/1273 answer:C correct_answer:C True
# answer: A
# question 438/1273 answer:A correct_answer:A True
# answer: D
# question 439/1273 answer:D correct_answer:C False
# answer: A
# question 440/1273 answer:A correct_answer:A True
# answer: D
# question 441/1273 answer:D correct_answer:D True
# answer: C
# question 442/1273 answer:C correct_answer:C True
# answer: C
# question 443/1273 answer:C correct_answer:C True
# answer: B
# question 444/1273 answer:B correct_answer:B True
# answer: C
# question 445/1273 answer:C correct_answer:C True
# answer: B
# question 446/1273 answer:B correct_answer:B True
# answer: A
# question 447/1273 answer:A correct_answer:A True
# answer: D
# question 448/1273 answer:D correct_answer:C False
# answer: B
# question 449/1273 answer:B correct_answer:D False
# answer: B
# question 450/1273 answer:B correct_answer:B True
# answer: C
# question 451/1273 answer:C correct_answer:B False
# answer: D
# question 452/1273 answer:D correct_answer:D True
# answer: C
# question 453/1273 answer:C correct_answer:B False
# answer: B
# question 454/1273 answer:B correct_answer:B True
# answer: D
# question 455/1273 answer:D correct_answer:D True
# answer: C
# question 456/1273 answer:C correct_answer:C True
# answer: B
# question 457/1273 answer:B correct_answer:B True
# answer: A
# question 458/1273 answer:A correct_answer:B False
# answer: C
# question 459/1273 answer:C correct_answer:C True
# answer: D
# question 460/1273 answer:D correct_answer:D True
# answer: B
# question 461/1273 answer:B correct_answer:A False
# answer: D
# question 462/1273 answer:D correct_answer:C False
# answer: A
# question 463/1273 answer:A correct_answer:B False
# answer: D
# question 464/1273 answer:D correct_answer:A False
# answer: B
# question 465/1273 answer:B correct_answer:B True
# answer: D
# question 466/1273 answer:D correct_answer:C False
# answer: B
# question 467/1273 answer:B correct_answer:B True
# answer: C
# question 468/1273 answer:C correct_answer:D False
# answer: A
# question 469/1273 answer:A correct_answer:A True
# answer: D
# question 470/1273 answer:D correct_answer:A False
# answer: C
# question 471/1273 answer:C correct_answer:A False
# answer: D
# question 472/1273 answer:D correct_answer:C False
# answer: C
# question 473/1273 answer:C correct_answer:C True
# answer: C
# question 474/1273 answer:C correct_answer:C True
# answer: B
# question 475/1273 answer:B correct_answer:B True
# answer: B
# question 476/1273 answer:B correct_answer:D False
# answer: C
# question 477/1273 answer:C correct_answer:C True
# answer: D
# question 478/1273 answer:D correct_answer:A False
# answer: C
# question 479/1273 answer:C correct_answer:C True
# answer: C
# question 480/1273 answer:C correct_answer:C True
# answer: D
# question 481/1273 answer:D correct_answer:B False
# answer: A
# question 482/1273 answer:A correct_answer:A True
# answer: B
# question 483/1273 answer:B correct_answer:B True
# answer: A
# question 484/1273 answer:A correct_answer:C False
# answer: C
# question 485/1273 answer:C correct_answer:C True
# answer: A
# question 486/1273 answer:A correct_answer:D False
# answer: D
# question 487/1273 answer:D correct_answer:B False
# answer: C
# question 488/1273 answer:C correct_answer:C True
# answer: A
# question 489/1273 answer:A correct_answer:A True
# answer: C
# question 490/1273 answer:C correct_answer:C True
# answer: C
# question 491/1273 answer:C correct_answer:C True
# answer: A
# question 492/1273 answer:A correct_answer:A True
# answer: B
# question 493/1273 answer:B correct_answer:C False
# answer: C
# question 494/1273 answer:C correct_answer:C True
# answer: A
# question 495/1273 answer:A correct_answer:A True
# answer: A
# question 496/1273 answer:A correct_answer:A True
# answer: C
# question 497/1273 answer:C correct_answer:C True
# answer: D
# question 498/1273 answer:D correct_answer:D True
# answer: C
# question 499/1273 answer:C correct_answer:A False
# answer: D
# question 500/1273 answer:D correct_answer:C False
# answer: A
# question 501/1273 answer:A correct_answer:B False
# answer: B
# question 502/1273 answer:B correct_answer:D False
# answer: B
# question 503/1273 answer:B correct_answer:B True
# answer: B
# question 504/1273 answer:B correct_answer:B True
# answer: B
# question 505/1273 answer:B correct_answer:B True
# answer: B
# question 506/1273 answer:B correct_answer:B True
# answer: A
# question 507/1273 answer:A correct_answer:A True
# answer: D
# question 508/1273 answer:D correct_answer:D True
# answer: C
# question 509/1273 answer:C correct_answer:B False
# answer: D
# question 510/1273 answer:D correct_answer:D True
# answer: A
# question 511/1273 answer:A correct_answer:A True
# answer: A
# question 512/1273 answer:A correct_answer:A True
# answer: A
# question 513/1273 answer:A correct_answer:B False
# answer: D
# question 514/1273 answer:D correct_answer:D True
# answer: C
# question 515/1273 answer:C correct_answer:A False
# answer: A
# question 516/1273 answer:A correct_answer:D False
# answer: D
# question 517/1273 answer:D correct_answer:D True
# answer: A
# question 518/1273 answer:A correct_answer:A True
# answer: B
# question 519/1273 answer:B correct_answer:B True
# answer: A
# question 520/1273 answer:A correct_answer:C False
# answer: B
# question 521/1273 answer:B correct_answer:B True
# answer: A
# question 522/1273 answer:A correct_answer:A True
# answer: C
# question 523/1273 answer:C correct_answer:C True
# answer: D
# question 524/1273 answer:D correct_answer:D True
# answer: D
# question 525/1273 answer:D correct_answer:B False
# answer: D
# question 526/1273 answer:D correct_answer:D True
# answer: C
# question 527/1273 answer:C correct_answer:C True
# answer: A
# question 528/1273 answer:A correct_answer:A True
# answer: A
# question 529/1273 answer:A correct_answer:C False
# answer: B
# question 530/1273 answer:B correct_answer:B True
# answer: A
# question 531/1273 answer:A correct_answer:A True
# answer: C
# question 532/1273 answer:C correct_answer:D False
# answer: B
# question 533/1273 answer:B correct_answer:B True
# answer: A
# question 534/1273 answer:A correct_answer:A True
# answer: B
# question 535/1273 answer:B correct_answer:B True
# answer: C
# question 536/1273 answer:C correct_answer:C True
# answer: D
# question 537/1273 answer:D correct_answer:D True
# answer: A
# question 538/1273 answer:A correct_answer:A True
# answer: A
# question 539/1273 answer:A correct_answer:A True
# answer: D
# question 540/1273 answer:D correct_answer:D True
# answer: B
# question 541/1273 answer:B correct_answer:D False
# answer: C
# question 542/1273 answer:C correct_answer:A False
# answer: B
# question 543/1273 answer:B correct_answer:B True
# answer: C
# question 544/1273 answer:C correct_answer:C True
# answer: C
# question 545/1273 answer:C correct_answer:B False
# answer: C
# question 546/1273 answer:C correct_answer:C True
# answer: C
# question 547/1273 answer:C correct_answer:D False
# answer: D
# question 548/1273 answer:D correct_answer:D True
# answer: D
# question 549/1273 answer:D correct_answer:D True
# answer: A
# question 550/1273 answer:A correct_answer:B False
# answer: C
# question 551/1273 answer:C correct_answer:A False
# answer: A
# question 552/1273 answer:A correct_answer:A True
# answer: A
# question 553/1273 answer:A correct_answer:A True
# answer: B
# question 554/1273 answer:B correct_answer:B True
# answer: A
# question 555/1273 answer:A correct_answer:A True
# answer: B
# question 556/1273 answer:B correct_answer:B True
# answer: A
# question 557/1273 answer:A correct_answer:A True
# answer: C
# question 558/1273 answer:C correct_answer:C True
# answer: B
# question 559/1273 answer:B correct_answer:B True
# answer: B
# question 560/1273 answer:B correct_answer:B True
# answer: A
# question 561/1273 answer:A correct_answer:A True
# answer: C
# question 562/1273 answer:C correct_answer:C True
# answer: B
# question 563/1273 answer:B correct_answer:B True
# answer: A
# question 564/1273 answer:A correct_answer:A True
# answer: B
# question 565/1273 answer:B correct_answer:A False
# answer: B
# question 566/1273 answer:B correct_answer:B True
# answer: B
# question 567/1273 answer:B correct_answer:B True
# answer: A
# question 568/1273 answer:A correct_answer:D False
# answer: A
# question 569/1273 answer:A correct_answer:A True
# answer: B
# question 570/1273 answer:B correct_answer:B True
# answer: A
# question 571/1273 answer:A correct_answer:A True
# answer: C
# question 572/1273 answer:C correct_answer:C True
# answer: C
# question 573/1273 answer:C correct_answer:C True
# answer: A
# question 574/1273 answer:A correct_answer:C False
# answer: B
# question 575/1273 answer:B correct_answer:B True
# answer: C
# question 576/1273 answer:C correct_answer:B False
# answer: C
# question 577/1273 answer:C correct_answer:D False
# answer: C
# question 578/1273 answer:C correct_answer:B False
# answer: A
# question 579/1273 answer:A correct_answer:A True
# answer: D
# question 580/1273 answer:D correct_answer:D True
# answer: A
# question 581/1273 answer:A correct_answer:A True
# answer: B
# question 582/1273 answer:B correct_answer:C False
# answer: D
# question 583/1273 answer:D correct_answer:D True
# answer: C
# question 584/1273 answer:C correct_answer:D False
# answer: D
# question 585/1273 answer:D correct_answer:D True
# answer: D
# question 586/1273 answer:D correct_answer:D True
# answer: B
# question 587/1273 answer:B correct_answer:B True
# answer: B
# question 588/1273 answer:B correct_answer:D False
# answer: B
# question 589/1273 answer:B correct_answer:A False
# answer: D
# question 590/1273 answer:D correct_answer:D True
# answer: C
# question 591/1273 answer:C correct_answer:C True
# answer: C
# question 592/1273 answer:C correct_answer:C True
# answer: B
# question 593/1273 answer:B correct_answer:A False
# answer: C
# question 594/1273 answer:C correct_answer:C True
# answer: C
# question 595/1273 answer:C correct_answer:C True
# answer: B
# question 596/1273 answer:B correct_answer:B True
# answer: C
# question 597/1273 answer:C correct_answer:C True
# answer: B
# question 598/1273 answer:B correct_answer:B True
# answer: B
# question 599/1273 answer:B correct_answer:B True
# answer: C
# question 600/1273 answer:C correct_answer:C True
# answer: D
# question 601/1273 answer:D correct_answer:D True
# answer: D
# question 602/1273 answer:D correct_answer:D True
# answer: B
# question 603/1273 answer:B correct_answer:A False
# answer: A
# question 604/1273 answer:A correct_answer:A True
# answer: A
# question 605/1273 answer:A correct_answer:A True
# answer: B
# question 606/1273 answer:B correct_answer:B True
# answer: D
# question 607/1273 answer:D correct_answer:D True
# answer: C
# question 608/1273 answer:C correct_answer:C True
# answer: C
# question 609/1273 answer:C correct_answer:C True
# answer: D
# question 610/1273 answer:D correct_answer:D True
# answer: A
# question 611/1273 answer:A correct_answer:A True
# answer: C
# question 612/1273 answer:C correct_answer:C True
# answer: A
# question 613/1273 answer:A correct_answer:A True
# answer: A
# question 614/1273 answer:A correct_answer:C False
# answer: C
# question 615/1273 answer:C correct_answer:C True
# answer: C
# question 616/1273 answer:C correct_answer:A False
# answer: B
# question 617/1273 answer:B correct_answer:D False
# answer: B
# question 618/1273 answer:B correct_answer:B True
# answer: C
# question 619/1273 answer:C correct_answer:C True
# answer: C
# question 620/1273 answer:C correct_answer:D False
# answer: C
# question 621/1273 answer:C correct_answer:C True
# answer: D
# question 622/1273 answer:D correct_answer:D True
# answer: C
# question 623/1273 answer:C correct_answer:C True
# answer: A
# question 624/1273 answer:A correct_answer:A True
# answer: D
# question 625/1273 answer:D correct_answer:D True
# answer: B
# question 626/1273 answer:B correct_answer:B True
# answer: D
# question 627/1273 answer:D correct_answer:D True
# answer: B
# question 628/1273 answer:B correct_answer:C False
# answer: D
# question 629/1273 answer:D correct_answer:C False
# answer: D
# question 630/1273 answer:D correct_answer:D True
# answer: C
# question 631/1273 answer:C correct_answer:D False
# answer: B
# question 632/1273 answer:B correct_answer:B True
# answer: D
# question 633/1273 answer:D correct_answer:D True
# answer: C
# question 634/1273 answer:C correct_answer:B False
# answer: B
# question 635/1273 answer:B correct_answer:A False
# answer: B
# question 636/1273 answer:B correct_answer:B True
# answer: A
# question 637/1273 answer:A correct_answer:A True
# answer: A
# question 638/1273 answer:A correct_answer:A True
# answer: A
# question 639/1273 answer:A correct_answer:A True
# answer: D
# question 640/1273 answer:D correct_answer:A False
# answer: D
# question 641/1273 answer:D correct_answer:D True
# answer: A
# question 642/1273 answer:A correct_answer:A True
# answer: B
# question 643/1273 answer:B correct_answer:A False
# answer: D
# question 644/1273 answer:D correct_answer:D True
# answer: B
# question 645/1273 answer:B correct_answer:B True
# answer: D
# question 646/1273 answer:D correct_answer:B False
# answer: B
# question 647/1273 answer:B correct_answer:B True
# answer: B
# question 648/1273 answer:B correct_answer:B True
# answer: A
# question 649/1273 answer:A correct_answer:A True
# answer: C
# question 650/1273 answer:C correct_answer:A False
# answer: C
# question 651/1273 answer:C correct_answer:C True
# answer: C
# question 652/1273 answer:C correct_answer:C True
# answer: C
# question 653/1273 answer:C correct_answer:C True
# answer: A
# question 654/1273 answer:A correct_answer:A True
# answer: D
# question 655/1273 answer:D correct_answer:A False
# answer: C
# question 656/1273 answer:C correct_answer:B False
# answer: D
# question 657/1273 answer:D correct_answer:D True
# answer: D
# question 658/1273 answer:D correct_answer:D True
# answer: C
# question 659/1273 answer:C correct_answer:C True
# answer: D
# question 660/1273 answer:D correct_answer:C False
# answer: A
# question 661/1273 answer:A correct_answer:A True
# answer: A
# question 662/1273 answer:A correct_answer:A True
# answer: D
# question 663/1273 answer:D correct_answer:D True
# answer: A
# question 664/1273 answer:A correct_answer:D False
# answer: D
# question 665/1273 answer:D correct_answer:C False
# answer: B
# question 666/1273 answer:B correct_answer:B True
# answer: B
# question 667/1273 answer:B correct_answer:A False
# answer: A
# question 668/1273 answer:A correct_answer:A True
# answer: B
# question 669/1273 answer:B correct_answer:B True
# answer: B
# question 670/1273 answer:B correct_answer:B True
# answer: C
# question 671/1273 answer:C correct_answer:D False
# answer: B
# question 672/1273 answer:B correct_answer:B True
# answer: B
# question 673/1273 answer:B correct_answer:B True
# answer: D
# question 674/1273 answer:D correct_answer:D True
# answer: A
# question 675/1273 answer:A correct_answer:A True
# answer: C
# question 676/1273 answer:C correct_answer:C True
# answer: B
# question 677/1273 answer:B correct_answer:A False
# answer: B
# question 678/1273 answer:B correct_answer:A False
# answer: A
# question 679/1273 answer:A correct_answer:B False
# answer: A
# question 680/1273 answer:A correct_answer:B False
# answer: D
# question 681/1273 answer:D correct_answer:D True
# answer: B
# question 682/1273 answer:B correct_answer:B True
# answer: D
# question 683/1273 answer:D correct_answer:D True
# answer: C
# question 684/1273 answer:C correct_answer:C True
# answer: D
# question 685/1273 answer:D correct_answer:B False
# answer: C
# question 686/1273 answer:C correct_answer:C True
# answer: A
# question 687/1273 answer:A correct_answer:A True
# answer: A
# question 688/1273 answer:A correct_answer:A True
# answer: C
# question 689/1273 answer:C correct_answer:A False
# answer: C
# question 690/1273 answer:C correct_answer:C True
# answer: C
# question 691/1273 answer:C correct_answer:A False
# answer: A
# question 692/1273 answer:A correct_answer:B False
# answer: C
# question 693/1273 answer:C correct_answer:C True
# answer: B
# question 694/1273 answer:B correct_answer:B True
# answer: A
# question 695/1273 answer:A correct_answer:A True
# answer: B
# question 696/1273 answer:B correct_answer:B True
# answer: D
# question 697/1273 answer:D correct_answer:D True
# answer: D
# question 698/1273 answer:D correct_answer:D True
# answer: A
# question 699/1273 answer:A correct_answer:A True
# answer: A
# question 700/1273 answer:A correct_answer:A True
# answer: B
# question 701/1273 answer:B correct_answer:B True
# answer: C
# question 702/1273 answer:C correct_answer:C True
# answer: D
# question 703/1273 answer:D correct_answer:C False
# answer: D
# question 704/1273 answer:D correct_answer:D True
# answer: D
# question 705/1273 answer:D correct_answer:D True
# answer: C
# question 706/1273 answer:C correct_answer:C True
# answer: B
# question 707/1273 answer:B correct_answer:B True
# answer: C
# question 708/1273 answer:C correct_answer:C True
# answer: C
# question 709/1273 answer:C correct_answer:A False
# answer: A
# question 710/1273 answer:A correct_answer:A True
# answer: C
# question 711/1273 answer:C correct_answer:C True
# answer: C
# question 712/1273 answer:C correct_answer:C True
# answer: C
# question 713/1273 answer:C correct_answer:C True
# answer: A
# question 714/1273 answer:A correct_answer:A True
# answer: C
# question 715/1273 answer:C correct_answer:B False
# answer: B
# question 716/1273 answer:B correct_answer:B True
# answer: D
# question 717/1273 answer:D correct_answer:C False
# answer: B
# question 718/1273 answer:B correct_answer:B True
# answer: B
# question 719/1273 answer:B correct_answer:D False
# answer: D
# question 720/1273 answer:D correct_answer:A False
# answer: D
# question 721/1273 answer:D correct_answer:B False
# answer: B
# question 722/1273 answer:B correct_answer:B True
# answer: D
# question 723/1273 answer:D correct_answer:D True
# answer: C
# question 724/1273 answer:C correct_answer:C True
# answer: D
# question 725/1273 answer:D correct_answer:D True
# answer: C
# question 726/1273 answer:C correct_answer:C True
# answer: D
# question 727/1273 answer:D correct_answer:D True
# answer: A
# question 728/1273 answer:A correct_answer:A True
# answer: C
# question 729/1273 answer:C correct_answer:C True
# answer: C
# question 730/1273 answer:C correct_answer:C True
# answer: D
# question 731/1273 answer:D correct_answer:D True
# answer: B
# question 732/1273 answer:B correct_answer:B True
# answer: B
# question 733/1273 answer:B correct_answer:B True
# answer: B
# question 734/1273 answer:B correct_answer:B True
# answer: C
# question 735/1273 answer:C correct_answer:C True
# answer: A
# question 736/1273 answer:A correct_answer:A True
# answer: D
# question 737/1273 answer:D correct_answer:A False
# answer: C
# question 738/1273 answer:C correct_answer:C True
# answer: A
# question 739/1273 answer:A correct_answer:A True
# answer: D
# question 740/1273 answer:D correct_answer:A False
# answer: D
# question 741/1273 answer:D correct_answer:D True
# answer: A
# question 742/1273 answer:A correct_answer:A True
# answer: D
# question 743/1273 answer:D correct_answer:B False
# answer: B
# question 744/1273 answer:B correct_answer:B True
# answer: C
# question 745/1273 answer:C correct_answer:C True
# answer: C
# question 746/1273 answer:C correct_answer:A False
# answer: C
# question 747/1273 answer:C correct_answer:B False
# answer: B
# question 748/1273 answer:B correct_answer:C False
# answer: A
# question 749/1273 answer:A correct_answer:A True
# answer: C
# question 750/1273 answer:C correct_answer:C True
# answer: B
# question 751/1273 answer:B correct_answer:B True
# answer: C
# question 752/1273 answer:C correct_answer:B False
# answer: C
# question 753/1273 answer:C correct_answer:C True
# answer: C
# question 754/1273 answer:C correct_answer:C True
# answer: B
# question 755/1273 answer:B correct_answer:B True
# answer: D
# question 756/1273 answer:D correct_answer:C False
# answer: B
# question 757/1273 answer:B correct_answer:B True
# answer: C
# question 758/1273 answer:C correct_answer:D False
# answer: B
# question 759/1273 answer:B correct_answer:D False
# answer: C
# question 760/1273 answer:C correct_answer:C True
# answer: B
# question 761/1273 answer:B correct_answer:B True
# answer: A
# question 762/1273 answer:A correct_answer:D False
# answer: A
# question 763/1273 answer:A correct_answer:C False
# answer: A
# question 764/1273 answer:A correct_answer:A True
# answer: D
# question 765/1273 answer:D correct_answer:C False
# answer: C
# question 766/1273 answer:C correct_answer:C True
# answer: D
# question 767/1273 answer:D correct_answer:D True
# answer: A
# question 768/1273 answer:A correct_answer:A True
# answer: B
# question 769/1273 answer:B correct_answer:B True
# answer: C
# question 770/1273 answer:C correct_answer:C True
# answer: D
# question 771/1273 answer:D correct_answer:B False
# answer: D
# question 772/1273 answer:D correct_answer:C False
# answer: B
# question 773/1273 answer:B correct_answer:D False
# answer: A
# question 774/1273 answer:A correct_answer:A True
# answer: D
# question 775/1273 answer:D correct_answer:D True
# answer: A
# question 776/1273 answer:A correct_answer:A True
# answer: B
# question 777/1273 answer:B correct_answer:B True
# answer: C
# question 778/1273 answer:C correct_answer:C True
# answer: D
# question 779/1273 answer:D correct_answer:C False
# answer: D
# question 780/1273 answer:D correct_answer:D True
# answer: D
# question 781/1273 answer:D correct_answer:C False
# answer: D
# question 782/1273 answer:D correct_answer:D True
# answer: D
# question 783/1273 answer:D correct_answer:D True
# answer: B
# question 784/1273 answer:B correct_answer:B True
# answer: D
# question 785/1273 answer:D correct_answer:B False
# answer: C
# question 786/1273 answer:C correct_answer:D False
# answer: C
# question 787/1273 answer:C correct_answer:D False
# answer: B
# question 788/1273 answer:B correct_answer:C False
# answer: C
# question 789/1273 answer:C correct_answer:C True
# answer: C
# question 790/1273 answer:C correct_answer:C True
# answer: D
# question 791/1273 answer:D correct_answer:B False
# answer: A
# question 792/1273 answer:A correct_answer:A True
# answer: B
# question 793/1273 answer:B correct_answer:B True
# answer: B
# question 794/1273 answer:B correct_answer:B True
# answer: D
# question 795/1273 answer:D correct_answer:D True
# answer: C
# question 796/1273 answer:C correct_answer:C True
# answer: C
# question 797/1273 answer:C correct_answer:C True
# answer: D
# question 798/1273 answer:D correct_answer:D True
# answer: D
# question 799/1273 answer:D correct_answer:C False
# answer: C
# question 800/1273 answer:C correct_answer:B False
# answer: B
# question 801/1273 answer:B correct_answer:B True
# answer: B
# question 802/1273 answer:B correct_answer:B True
# answer: A
# question 803/1273 answer:A correct_answer:D False
# answer: B
# question 804/1273 answer:B correct_answer:A False
# answer: A
# question 805/1273 answer:A correct_answer:A True
# answer: B
# question 806/1273 answer:B correct_answer:B True
# answer: A
# question 807/1273 answer:A correct_answer:A True
# answer: B
# question 808/1273 answer:B correct_answer:A False
# answer: C
# question 809/1273 answer:C correct_answer:C True
# answer: B
# ...
# answer: B
# question 1011/1273 answer:B correct_answer:B True
# answer: D
# question 1012/1273 answer:D correct_answer:D True
# answer: A
# question 1013/1273 answer:A correct_answer:A True
# answer: C
# question 1014/1273 answer:C correct_answer:C True
# answer: B
# question 1015/1273 answer:B correct_answer:B True
# answer: A
# question 1016/1273 answer:A correct_answer:A True
# answer: C
# question 1017/1273 answer:C correct_answer:C True
# answer: D
# question 1018/1273 answer:D correct_answer:D True
# answer: B
# question 1019/1273 answer:B correct_answer:B True
# answer: A
# question 1020/1273 answer:A correct_answer:A True
# answer: B
# question 1021/1273 answer:B correct_answer:C False
# answer: C
# question 1022/1273 answer:C correct_answer:D False
# answer: A
# question 1023/1273 answer:A correct_answer:A True
# answer: A
# question 1024/1273 answer:A correct_answer:C False
# answer: C
# question 1025/1273 answer:C correct_answer:C True
# answer: D
# question 1026/1273 answer:D correct_answer:D True
# answer: A
# question 1027/1273 answer:A correct_answer:A True
# answer: B
# question 1028/1273 answer:B correct_answer:B True
# answer: D
# question 1029/1273 answer:D correct_answer:D True
# answer: A
# question 1030/1273 answer:A correct_answer:A True
# answer: C
# question 1031/1273 answer:C correct_answer:A False
# answer: D
# question 1032/1273 answer:D correct_answer:D True
# answer: B
# question 1033/1273 answer:B correct_answer:B True
# answer: B
# question 1034/1273 answer:B correct_answer:B True
# answer: C
# question 1035/1273 answer:C correct_answer:B False
# answer: B
# question 1036/1273 answer:B correct_answer:B True
# answer: B
# question 1037/1273 answer:B correct_answer:B True
# answer: A
# question 1038/1273 answer:A correct_answer:A True
# answer: C
# question 1039/1273 answer:C correct_answer:A False
# answer: B
# question 1040/1273 answer:B correct_answer:B True
# answer: C
# question 1041/1273 answer:C correct_answer:B False
# answer: C
# question 1042/1273 answer:C correct_answer:C True
# answer: B
# question 1043/1273 answer:B correct_answer:D False
# answer: D
# question 1044/1273 answer:D correct_answer:D True
# answer: B
# question 1045/1273 answer:B correct_answer:B True
# answer: A
# question 1046/1273 answer:A correct_answer:A True
# answer: B
# question 1047/1273 answer:B correct_answer:B True
# answer: B
# question 1048/1273 answer:B correct_answer:B True
# answer: B
# question 1049/1273 answer:B correct_answer:B True
# answer: C
# question 1050/1273 answer:C correct_answer:C True
# answer: B
# question 1051/1273 answer:B correct_answer:C False
# answer: A
# question 1052/1273 answer:A correct_answer:C False
# answer: A
# question 1053/1273 answer:A correct_answer:B False
# answer: B
# question 1054/1273 answer:B correct_answer:B True
# answer: A
# question 1055/1273 answer:A correct_answer:A True
# answer: C
# question 1056/1273 answer:C correct_answer:C True
# answer: D
# question 1057/1273 answer:D correct_answer:D True
# answer: A
# question 1058/1273 answer:A correct_answer:A True
# answer: C
# question 1059/1273 answer:C correct_answer:C True
# answer: A
# question 1060/1273 answer:A correct_answer:A True
# answer: B
# question 1061/1273 answer:B correct_answer:C False
# answer: D
# question 1062/1273 answer:D correct_answer:D True
# answer: A
# question 1063/1273 answer:A correct_answer:A True
# answer: D
# question 1064/1273 answer:D correct_answer:D True
# answer: D
# question 1065/1273 answer:D correct_answer:D True
# answer: A
# question 1066/1273 answer:A correct_answer:A True
# answer: A
# question 1067/1273 answer:A correct_answer:A True
# answer: C
# question 1068/1273 answer:C correct_answer:C True
# answer: B
# question 1069/1273 answer:B correct_answer:B True
# answer: A
# question 1070/1273 answer:A correct_answer:A True
# answer: D
# question 1071/1273 answer:D correct_answer:D True
# answer: A
# question 1072/1273 answer:A correct_answer:A True
# answer: D
# question 1073/1273 answer:D correct_answer:D True
# answer: C
# question 1074/1273 answer:C correct_answer:D False
# answer: A
# question 1075/1273 answer:A correct_answer:C False
# answer: D
# question 1076/1273 answer:D correct_answer:D True
# answer: D
# question 1077/1273 answer:D correct_answer:B False
# answer: C
# question 1078/1273 answer:C correct_answer:A False
# answer: A
# question 1079/1273 answer:A correct_answer:A True
# answer: A
# question 1080/1273 answer:A correct_answer:D False
# answer: A
# question 1081/1273 answer:A correct_answer:C False
# answer: D
# question 1082/1273 answer:D correct_answer:D True
# answer: B
# question 1083/1273 answer:B correct_answer:B True
# answer: A
# question 1084/1273 answer:A correct_answer:A True
# answer: D
# question 1085/1273 answer:D correct_answer:D True
# answer: A
# question 1086/1273 answer:A correct_answer:A True
# answer: B
# question 1087/1273 answer:B correct_answer:B True
# answer: C
# question 1088/1273 answer:C correct_answer:C True
# answer: A
# question 1089/1273 answer:A correct_answer:B False
# answer: B
# question 1090/1273 answer:B correct_answer:B True
# answer: C
# question 1091/1273 answer:C correct_answer:C True
# answer: C
# question 1092/1273 answer:C correct_answer:C True
# answer: B
# question 1093/1273 answer:B correct_answer:B True
# answer: D
# question 1094/1273 answer:D correct_answer:B False
# answer: C
# question 1095/1273 answer:C correct_answer:C True
# answer: D
# question 1096/1273 answer:D correct_answer:C False
# answer: C
# question 1097/1273 answer:C correct_answer:C True
# answer: C
# question 1098/1273 answer:C correct_answer:C True
# answer: D
# question 1099/1273 answer:D correct_answer:D True
# answer: A
# question 1100/1273 answer:A correct_answer:A True
# answer: B
# question 1101/1273 answer:B correct_answer:A False
# answer: A
# question 1102/1273 answer:A correct_answer:A True
# answer: D
# question 1103/1273 answer:D correct_answer:C False
# answer: C
# question 1104/1273 answer:C correct_answer:C True
# answer: B
# question 1105/1273 answer:B correct_answer:B True
# answer: A
# question 1106/1273 answer:A correct_answer:A True
# answer: A
# question 1107/1273 answer:A correct_answer:B False
# answer: C
# question 1108/1273 answer:C correct_answer:A False
# answer: A
# question 1109/1273 answer:A correct_answer:C False
# answer: A
# question 1110/1273 answer:A correct_answer:B False
# answer: o
# question 1111/1273 answer:o correct_answer:C False
# answer: C
# question 1112/1273 answer:C correct_answer:C True
# answer: C
# question 1113/1273 answer:C correct_answer:C True
# answer: D
# question 1114/1273 answer:D correct_answer:D True
# answer: C
# question 1115/1273 answer:C correct_answer:C True
# answer: D
# question 1116/1273 answer:D correct_answer:D True
# answer: C
# question 1117/1273 answer:C correct_answer:C True
# answer: B
# question 1118/1273 answer:B correct_answer:C False
# answer: C
# question 1119/1273 answer:C correct_answer:C True
# answer: D
# question 1120/1273 answer:D correct_answer:D True
# answer: C
# question 1121/1273 answer:C correct_answer:C True
# answer: A
# question 1122/1273 answer:A correct_answer:A True
# answer: A
# question 1123/1273 answer:A correct_answer:A True
# answer: D
# question 1124/1273 answer:D correct_answer:D True
# answer: D
# question 1125/1273 answer:D correct_answer:D True
# answer: B
# question 1126/1273 answer:B correct_answer:C False
# answer: D
# question 1127/1273 answer:D correct_answer:D True
# answer: C
# question 1128/1273 answer:C correct_answer:C True
# answer: D
# question 1129/1273 answer:D correct_answer:A False
# answer: C
# question 1130/1273 answer:C correct_answer:C True
# answer: A
# question 1131/1273 answer:A correct_answer:A True
# answer: A
# question 1132/1273 answer:A correct_answer:A True
# answer: D
# question 1133/1273 answer:D correct_answer:D True
# answer: B
# question 1134/1273 answer:B correct_answer:B True
# answer: D
# question 1135/1273 answer:D correct_answer:A False
# answer: A
# question 1136/1273 answer:A correct_answer:D False
# answer: A
# question 1137/1273 answer:A correct_answer:D False
# answer: C
# question 1138/1273 answer:C correct_answer:C True
# answer: D
# question 1139/1273 answer:D correct_answer:D True
# answer: A
# question 1140/1273 answer:A correct_answer:A True
# answer: A
# question 1141/1273 answer:A correct_answer:B False
# answer: A
# question 1142/1273 answer:A correct_answer:B False
# answer: A
# question 1143/1273 answer:A correct_answer:A True
# answer: C
# question 1144/1273 answer:C correct_answer:C True
# answer: C
# question 1145/1273 answer:C correct_answer:C True
# answer: A
# question 1146/1273 answer:A correct_answer:A True
# answer: C
# question 1147/1273 answer:C correct_answer:C True
# answer: A
# question 1148/1273 answer:A correct_answer:A True
# answer: A
# question 1149/1273 answer:A correct_answer:A True
# answer: C
# question 1150/1273 answer:C correct_answer:B False
# answer: A
# question 1151/1273 answer:A correct_answer:A True
# answer: A
# question 1152/1273 answer:A correct_answer:A True
# answer: B
# question 1153/1273 answer:B correct_answer:B True
# answer: D
# question 1154/1273 answer:D correct_answer:A False
# answer: D
# question 1155/1273 answer:D correct_answer:D True
# answer: D
# question 1156/1273 answer:D correct_answer:D True
# answer: D
# question 1157/1273 answer:D correct_answer:C False
# answer: D
# question 1158/1273 answer:D correct_answer:D True
# answer: D
# question 1159/1273 answer:D correct_answer:D True
# answer: A
# question 1160/1273 answer:A correct_answer:A True
# answer: C
# question 1161/1273 answer:C correct_answer:C True
# answer: C
# question 1162/1273 answer:C correct_answer:B False
# answer: B
# question 1163/1273 answer:B correct_answer:D False
# answer: D
# question 1164/1273 answer:D correct_answer:B False
# answer: B
# question 1165/1273 answer:B correct_answer:A False
# answer: B
# question 1166/1273 answer:B correct_answer:B True
# answer: C
# question 1167/1273 answer:C correct_answer:C True
# answer: A
# question 1168/1273 answer:A correct_answer:A True
# answer: A
# question 1169/1273 answer:A correct_answer:A True
# answer: C
# question 1170/1273 answer:C correct_answer:C True
# answer: B
# question 1171/1273 answer:B correct_answer:A False
# answer: C
# question 1172/1273 answer:C correct_answer:C True
# answer: D
# question 1173/1273 answer:D correct_answer:D True
# answer: A
# question 1174/1273 answer:A correct_answer:A True
# answer: D
# question 1175/1273 answer:D correct_answer:C False
# answer: B
# question 1176/1273 answer:B correct_answer:B True
# answer: C
# question 1177/1273 answer:C correct_answer:D False
# answer: B
# question 1178/1273 answer:B correct_answer:B True
# answer: B
# question 1179/1273 answer:B correct_answer:B True
# answer: A
# question 1180/1273 answer:A correct_answer:C False
# answer: C
# question 1181/1273 answer:C correct_answer:A False
# answer: D
# question 1182/1273 answer:D correct_answer:D True
# answer: A
# question 1183/1273 answer:A correct_answer:A True
# answer: C
# question 1184/1273 answer:C correct_answer:B False
# answer: D
# question 1185/1273 answer:D correct_answer:D True
# answer: C
# question 1186/1273 answer:C correct_answer:C True
# answer: B
# question 1187/1273 answer:B correct_answer:B True
# answer: A
# question 1188/1273 answer:A correct_answer:A True
# answer: B
# question 1189/1273 answer:B correct_answer:B True
# answer: A
# question 1190/1273 answer:A correct_answer:C False
# answer: D
# question 1191/1273 answer:D correct_answer:D True
# answer: C
# question 1192/1273 answer:C correct_answer:C True
# answer: A
# question 1193/1273 answer:A correct_answer:A True
# answer: C
# question 1194/1273 answer:C correct_answer:C True
# answer: C
# question 1195/1273 answer:C correct_answer:D False
# answer: A
# question 1196/1273 answer:A correct_answer:A True
# answer: C
# question 1197/1273 answer:C correct_answer:C True
# answer: C
# question 1198/1273 answer:C correct_answer:C True
# answer: C
# question 1199/1273 answer:C correct_answer:B False
# answer: A
# question 1200/1273 answer:A correct_answer:A True
# answer: B
# question 1201/1273 answer:B correct_answer:B True
# answer: C
# question 1202/1273 answer:C correct_answer:C True
# answer: A
# question 1203/1273 answer:A correct_answer:A True
# answer: C
# question 1204/1273 answer:C correct_answer:C True
# answer: A
# question 1205/1273 answer:A correct_answer:A True
# answer: A
# question 1206/1273 answer:A correct_answer:D False
# answer: A
# question 1207/1273 answer:A correct_answer:A True
# answer: B
# question 1208/1273 answer:B correct_answer:B True
# answer: D
# question 1209/1273 answer:D correct_answer:D True
# answer: B
# question 1210/1273 answer:B correct_answer:A False
# answer: D
# question 1211/1273 answer:D correct_answer:C False
# answer: C
# question 1212/1273 answer:C correct_answer:C True
# answer: B
# question 1213/1273 answer:B correct_answer:B True
# answer: D
# question 1214/1273 answer:D correct_answer:D True
# answer: A
# question 1215/1273 answer:A correct_answer:A True
# answer: A
# question 1216/1273 answer:A correct_answer:A True
# answer: A
# question 1217/1273 answer:A correct_answer:A True
# answer: A
# question 1218/1273 answer:A correct_answer:D False
# answer: A
# question 1219/1273 answer:A correct_answer:B False
# answer: C
# question 1220/1273 answer:C correct_answer:C True
# answer: B
# question 1221/1273 answer:B correct_answer:A False
# answer: B
# question 1222/1273 answer:B correct_answer:A False
# answer: B
# question 1223/1273 answer:B correct_answer:C False
# answer: A
# question 1224/1273 answer:A correct_answer:A True
# answer: B
# question 1225/1273 answer:B correct_answer:D False
# answer: B
# question 1226/1273 answer:B correct_answer:B True
# answer: D
# question 1227/1273 answer:D correct_answer:D True
# answer: D
# question 1228/1273 answer:D correct_answer:C False
# answer: B
# question 1229/1273 answer:B correct_answer:B True
# answer: D
# question 1230/1273 answer:D correct_answer:C False
# answer: D
# question 1231/1273 answer:D correct_answer:D True
# answer: C
# question 1232/1273 answer:C correct_answer:A False
# answer: A
# question 1233/1273 answer:A correct_answer:A True
# answer: B
# question 1234/1273 answer:B correct_answer:A False
# answer: D
# question 1235/1273 answer:D correct_answer:B False
# answer: [invalid]
# question 1236/1273 answer:[invalid] correct_answer:A False
# answer: B
# question 1237/1273 answer:B correct_answer:B True
# answer: C
# question 1238/1273 answer:C correct_answer:A False
# answer: C
# question 1239/1273 answer:C correct_answer:C True
# answer: C
# question 1240/1273 answer:C correct_answer:C True
# answer: A
# question 1241/1273 answer:A correct_answer:A True
# answer: C
# question 1242/1273 answer:C correct_answer:D False
# answer: B
# question 1243/1273 answer:B correct_answer:B True
# answer: D
# question 1244/1273 answer:D correct_answer:D True
# answer: D
# question 1245/1273 answer:D correct_answer:A False
# answer: A
# question 1246/1273 answer:A correct_answer:B False
# answer: C
# question 1247/1273 answer:C correct_answer:C True
# answer: A
# question 1248/1273 answer:A correct_answer:A True
# answer: D
# question 1249/1273 answer:D correct_answer:D True
# answer: B
# question 1250/1273 answer:B correct_answer:D False
# answer: A
# question 1251/1273 answer:A correct_answer:A True
# answer: A
# question 1252/1273 answer:A correct_answer:A True
# answer: B
# question 1253/1273 answer:B correct_answer:B True
# answer: B
# question 1254/1273 answer:B correct_answer:B True
# answer: B
# question 1255/1273 answer:B correct_answer:B True
# answer: B
# question 1256/1273 answer:B correct_answer:A False
# answer: A
# question 1257/1273 answer:A correct_answer:A True
# answer: C
# question 1258/1273 answer:C correct_answer:D False
# answer: A
# question 1259/1273 answer:A correct_answer:A True
# answer: B
# question 1260/1273 answer:B correct_answer:B True
# answer: A
# question 1261/1273 answer:A correct_answer:B False
# answer: C
# question 1262/1273 answer:C correct_answer:C True
# answer: D
# question 1263/1273 answer:D correct_answer:B False
# answer: A
# question 1264/1273 answer:A correct_answer:A True
# answer: C
# question 1265/1273 answer:C correct_answer:B False
# answer: B
# question 1266/1273 answer:B correct_answer:B True
# answer: B
# question 1267/1273 answer:B correct_answer:C False
# answer: B
# question 1268/1273 answer:B correct_answer:B True
# answer: D
# question 1269/1273 answer:D correct_answer:D True
# answer: B
# question 1270/1273 answer:B correct_answer:D False
# answer: B
# question 1271/1273 answer:B correct_answer:B True
# answer: C
# question 1272/1273 answer:C correct_answer:C True
# answer: C
# question 1273/1273 answer:C correct_answer:C True
# Total questions: 1273, correct: 894, accuracy: 0.7022780832678712
# elapse_time: 9269.415498971939

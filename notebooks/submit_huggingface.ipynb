# %%
from huggingface_hub import login, upload_folder

login()

# %%
path = "/projects/sciences/computing/sheju347/MedicalQA/train/saved_models/base/10-15-UltraMedical-batchsize8-bf16"

upload_folder(folder_path=path, repo_id="Junyi-Shen/Junyi-Phi3-mini-UltraMedical", repo_type="model")
# Out:
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...cal-batchsize8-bf16/tokenizer.model:  75%|#######4  |  374kB /  500kB
#   ...bf16/checkpoint-51200/rng_state.pth:  77%|#######7  | 11.3kB / 14.6kB
#   ...f16/checkpoint-102400/rng_state.pth:  77%|#######7  | 11.3kB / 14.6kB
#   ...00/model-00002-of-00002.safetensors:   0%|          |  611kB / 2.67GB
#   ...00/model-00002-of-00002.safetensors:   0%|          |  616kB / 2.67GB
#   ...00/model-00001-of-00002.safetensors:   0%|          |  711kB / 4.97GB
#   ...00/model-00002-of-00002.safetensors:   0%|          |  616kB / 2.67GB
#   ...16/model-00002-of-00002.safetensors:   0%|          |  616kB / 2.67GB
#   ...00/model-00001-of-00002.safetensors:   0%|          |  688kB / 4.97GB
#   ...16/model-00001-of-00002.safetensors:   0%|          |  688kB / 4.97GB
# ...

# %%
lora_path = "/projects/sciences/computing/sheju347/MedicalQA/train/saved_models/LoRA/Junyi-Phi3-mini-context-aware-lora-adapter/10-17-new-base-model-1e-4-batch8-LoRA-1e-4-r16/"

upload_folder(folder_path=lora_path, repo_id="Junyi-Shen/Junyi-Phi3-mini-context-lora-adapter", repo_type="model")
# Out:
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...atch8-LoRA-1e-4-r16/tokenizer.model: 100%|##########|  500kB /  500kB
#   ...4-r16/checkpoint-21024/scheduler.pt: 100%|##########| 1.47kB / 1.47kB
#   ...-r16/checkpoint-21024/rng_state.pth: 100%|##########| 14.6kB / 14.6kB
#   .../checkpoint-21024/training_args.bin: 100%|##########| 5.78kB / 5.78kB
#   ...4-r16/checkpoint-21024/optimizer.pt: 100%|##########| 25.2MB / 25.2MB
#   .../checkpoint-14016/training_args.bin: 100%|##########| 5.78kB / 5.78kB
#   ...-r16/checkpoint-14016/rng_state.pth:  77%|#######7  | 11.3kB / 14.6kB
#   ...int-21024/adapter_model.safetensors: 100%|##########| 12.6MB / 12.6MB
#   ...4-r16/checkpoint-7008/rng_state.pth:  77%|#######7  | 11.3kB / 14.6kB
#   ...-1e-4-r16/adapter_model.safetensors: 100%|##########| 12.6MB / 12.6MB
# ...
